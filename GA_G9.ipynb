# %%
import numpy as np
from sko.GA import GA
import pandas as pd
import matplotlib.pyplot as plt

# %%
def g9(x):
    return (x[0]-10)**2 + 5*(x[1]-12)**2 + x[2]**4 +3*(x[3]-11)**2 +10*x[4]**6 +7*x[5]**2 + x[6]**4 -4*x[5]*x[6] -10*x[5] -8*x[6]

# %%
ueq = [
    lambda x: -127 + 2*x[0]**2 + 3*x[1]**4 + x[2] + 4*x[3]**2 + 5*x[4],
    lambda x: -282 + 7*x[0] + 3*x[1] + 10*x[2]**2 + x[3] - x[4],
    lambda x: -196 + 23*x[0] + x[1]**2 + 6*x[5]**2 - 8*x[6],
    lambda x: 4*x[0]**2 + x[1]**2 - 3*x[0]*x[1] + 2*x[2]**2 + 5*x[5] - 11*x[6]
]

# %%
ga = GA(func=g9, n_dim=7, size_pop=50, max_iter=100, prob_mut=0.01, lb=[-10] * 7, ub=[10] * 7, constraint_ueq = ueq, precision=1e-7)
best_x, best_y = ga.run()
print('best_x:', best_x, '\n', 'best_y:', best_y)
# Out:
# best_x: [ 1.86696415  1.85545218 -0.35411071  4.68672378 -0.60934324  1.12745461
#   1.40557003]
#  best_y: [684.74871061]

# %%
Y_history = pd.DataFrame(ga.all_history_Y)
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()
