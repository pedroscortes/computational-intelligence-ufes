# %%
import numpy as np
from sko.DE import DE
import pandas as pd
import matplotlib.pyplot as plt

# %%
def f5(x):
    return np.sum([xi**2 - 10 * np.cos(2 * np.pi * xi) + 10 for i, xi in enumerate(x, 1) if i <= 30])

# %%
de = DE(func=f5, n_dim=30, size_pop=100, max_iter=500, lb=[-5.12] * 30, ub=[5.12] * 30)

best_x, best_y = de.run()
print('best_x:', best_x, '\n', 'best_y:', best_y)
# Out:
# best_x: [-0.16072194  1.07257824 -0.97801798  0.95498918  1.09846639  0.02687353
#   0.04618589 -0.8209076  -2.0840161   2.00139656  0.97078236  1.99886169
#  -0.03834791  1.82764907  0.0187036   1.0729754  -0.09044514 -0.00929247
#  -0.0155917   2.9789155   0.98008392  1.02920643  0.96928414  1.07290507
#   0.94068547 -2.02897075 -0.00951214  1.03453426  0.13173484  0.1401898 ]
#  best_y: [75.50261187]

# %%
Y_history = pd.DataFrame(de.all_history_Y)
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()
