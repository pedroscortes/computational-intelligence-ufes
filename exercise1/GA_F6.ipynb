# %%
import numpy as np
from sko.GA import GA
import pandas as pd
import matplotlib.pyplot as plt

# %%
def f6(x):
  n = len(x)
  term_1 = np.sum(np.power(x, 2)) / 4000
  term_2 = np.prod(np.cos(x / np.sqrt(np.arange(1, n + 1))))
  return term_1 - term_2 + 1

# %%
ga = GA(func=f6, n_dim=30, size_pop=100, max_iter=1000, prob_mut=0.001, lb=[-600] * 30, ub=[600] * 30, precision=1e-7)
best_x, best_y = ga.run()
print('best_x:', best_x, '\n', 'best_y:', best_y)
# Out:
# best_x: [-1.36939343e-04 -1.23179052e-04  2.38709617e-04 -5.90190757e-04
#   1.02573540e-04  4.36173286e-04 -2.87254807e-04 -1.14168506e-04
#   2.99303792e-05  1.77521724e-04  5.40388282e-04  4.09351196e-04
#   3.03599518e-04 -8.57014675e-04 -2.44908733e-03 -2.34843465e-03
#   4.39585419e-03 -3.04986024e-03  8.87957867e-04  1.64658995e-03
#   6.31785952e-05  4.53914981e-04 -2.52221944e-03 -1.32364221e-05
#  -1.29776308e-03 -9.44675412e-04 -1.59427291e-03  3.08838207e-04
#  -8.32567457e-04 -3.31958290e-04]
#  best_y: [1.70006186e-06]

# %%
Y_history = pd.DataFrame(ga.all_history_Y)
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()
