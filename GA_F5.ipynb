# %%
import numpy as np
from sko.GA import GA
import pandas as pd
import matplotlib.pyplot as plt

# %%
def f5(x):
    return np.sum([xi**2 - 10 * np.cos(2 * np.pi * xi) + 10 for i, xi in enumerate(x, 1) if i <= 30])

# %%
ga = GA(func=f5, n_dim=30, size_pop=100, max_iter=100, prob_mut=0.001, lb=[-5.12] * 30, ub=[5.12] * 30, precision=1e-7)
best_x, best_y = ga.run()
print('best_x:', best_x, '\n', 'best_y:', best_y)
# Out:
# best_x: [ 0.0271484  -1.00631161  0.02762119  0.95087086 -0.01696743  1.98784925
#   0.9597263   0.98768063  0.99133527 -1.99140302  0.01718891  0.95692136
#  -0.99467877  1.95706502  0.99256749 -1.99329778 -0.98108952  1.00058575
#  -1.97131742  0.02009617  0.00398655 -1.96822973  1.00723935 -1.95860258
#  -0.03237629 -0.01926159  1.02694173  0.00649593  1.01056012 -1.98459615]
#  best_y: [47.40876099]

# %%
Y_history = pd.DataFrame(ga.all_history_Y)
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()
